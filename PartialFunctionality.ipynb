# %%
from OurTrainingTools2D import *
# Out:
# =========== Random Seed: 788 ===========

# %% [markdown]
# ## GW

# %%
DataFolder = '/data3/WZ_new_project/h5/Ideal_Data'

td = OurTrainingData([DataFolder + '/ChP_pt300_sm_1.h5',
                     ],
                    [DataFolder + '/ChP_pt300_gwm5e-2.h5',
                     DataFolder + '/ChP_pt300_gwm1e-1.h5',
                     DataFolder + '/ChP_pt300_gwm2e-1.h5',                     
                     DataFolder + '/ChP_pt300_gw5e-2.h5',
                     DataFolder + '/ChP_pt300_gw1e-1.h5',
                     DataFolder + '/ChP_pt300_gw2e-1.h5'],
                     process = 'W+Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

random_seed = torch.randint(0, 1339, (1,)).item()
OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChPgw_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')


td = OurTrainingData([DataFolder + '/ChM_pt300_sm_1.h5',
                     ],
                     [DataFolder + '/ChM_pt300_gwm5e-2.h5',
                     DataFolder + '/ChM_pt300_gwm1e-1.h5',
                     DataFolder + '/ChM_pt300_gwm2e-1.h5',                     
                     DataFolder + '/ChM_pt300_gw5e-2.h5',
                     DataFolder + '/ChM_pt300_gw1e-1.h5',
                     DataFolder + '/ChM_pt300_gw2e-1.h5'],
                     process = 'W-Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChMgW_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')
# Out:
# Loading Data Files for Process: W+Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gwm5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gwm1e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.2}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gwm2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gw5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gw1e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.2}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gw2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_sm_1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.741835
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[ 0.0000, -0.0500]], dtype=torch.float64)   500000         0.814992
# tensor([[ 0.0000, -0.1000]], dtype=torch.float64)   500000         1.03408
# tensor([[ 0.0000, -0.2000]], dtype=torch.float64)   500000         1.91084
# tensor([[0.0000, 0.0500]], dtype=torch.float64)     500000         0.815234
# tensor([[0.0000, 0.1000]], dtype=torch.float64)     500000         1.03439
# tensor([[0.0000, 0.2000]], dtype=torch.float64)     500000         1.91103
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[ 0.0000, -0.0500]], dtype=torch.float64)     500000    500000   500000
# tensor([[ 0.0000, -0.1000]], dtype=torch.float64)     500000    500000   500000
# tensor([[ 0.0000, -0.2000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.0000, 0.0500]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0000, 0.1000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0000, 0.2000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 23.97 sec, time left 6:02:50.934081 sec) loss 0.24341130
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 10 epoch.pth
# Training epoch 100 (took 214.38 sec, time left 6:29:21.818774 sec) loss 0.20845869
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 100 epoch.pth
# Training epoch 500 (took 954.94 sec, time left 6:17:05.116437 sec) loss 0.20556290
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 500 epoch.pth
# Training epoch 1000 (took 1207.77 sec, time left 5:59:45.695289 sec) loss 0.20505281
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 1000 epoch.pth
# Training epoch 2000 (took 2367.32 sec, time left 5:17:41.665060 sec) loss 0.20475747
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 2000 epoch.pth
# Training epoch 3000 (took 2367.28 sec, time left 4:37:21.982864 sec) loss 0.20464465
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 3000 epoch.pth
# Training epoch 4000 (took 2430.36 sec, time left 3:59:03.082611 sec) loss 0.20456420
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 4000 epoch.pth
# Training epoch 5000 (took 2414.15 sec, time left 3:19:35.401446 sec) loss 0.20450480
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 5000 epoch.pth
# Training epoch 6000 (took 2361.58 sec, time left 2:39:17.201821 sec) loss 0.20446786
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 6000 epoch.pth
# Training epoch 7000 (took 2368.92 sec, time left 1:59:18.317903 sec) loss 0.20443848
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 7000 epoch.pth
# Training epoch 8000 (took 2361.89 sec, time left 1:19:25.167998 sec) loss 0.20441481
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 8000 epoch.pth
# Training epoch 9000 (took 2365.98 sec, time left 0:39:39.417609 sec) loss 0.20440045
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 9000 epoch.pth
# Training epoch 10000 (took 2367.84 sec, time left -1 day, 23:59:57.619596 sec) loss 0.20437841
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed1093), Final.pth
# Loading Data Files for Process: W-Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gwm5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gwm1e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.2}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gwm2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gw5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gw1e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.2}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gw2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_sm_1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.329009
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[ 0.0000, -0.0500]], dtype=torch.float64)   500000         0.358355
# tensor([[ 0.0000, -0.1000]], dtype=torch.float64)   500000         0.446333
# tensor([[ 0.0000, -0.2000]], dtype=torch.float64)   500000         0.798199
# tensor([[0.0000, 0.0500]], dtype=torch.float64)     500000         0.358314
# tensor([[0.0000, 0.1000]], dtype=torch.float64)     500000         0.446264
# tensor([[0.0000, 0.2000]], dtype=torch.float64)     500000         0.798166
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[ 0.0000, -0.0500]], dtype=torch.float64)     500000    500000   500000
# tensor([[ 0.0000, -0.1000]], dtype=torch.float64)     500000    500000   500000
# tensor([[ 0.0000, -0.2000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.0000, 0.0500]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0000, 0.1000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0000, 0.2000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 23.48 sec, time left 5:55:23.160148 sec) loss 0.24972880
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 10 epoch.pth
# Training epoch 100 (took 211.33 sec, time left 6:23:34.581286 sec) loss 0.21546093
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 100 epoch.pth
# Training epoch 500 (took 939.74 sec, time left 6:11:09.850812 sec) loss 0.21115406
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 500 epoch.pth
# Training epoch 1000 (took 1175.77 sec, time left 5:52:09.534599 sec) loss 0.21002564
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 1000 epoch.pth
# Training epoch 2000 (took 2364.06 sec, time left 5:14:05.796731 sec) loss 0.20964217
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 2000 epoch.pth
# Training epoch 3000 (took 2370.11 sec, time left 4:35:22.642471 sec) loss 0.20951052
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 3000 epoch.pth
# Training epoch 4000 (took 2374.07 sec, time left 3:56:21.951786 sec) loss 0.20943348
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 4000 epoch.pth
# Training epoch 5000 (took 2368.61 sec, time left 3:17:02.454069 sec) loss 0.20938048
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 5000 epoch.pth
# Training epoch 6000 (took 2371.94 sec, time left 2:37:42.138140 sec) loss 0.20934604
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 6000 epoch.pth
# Training epoch 7000 (took 2438.83 sec, time left 1:58:47.155010 sec) loss 0.20930244
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 7000 epoch.pth
# Training epoch 8000 (took 2445.51 sec, time left 1:19:27.884013 sec) loss 0.20926991
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 8000 epoch.pth
# Training epoch 9000 (took 2445.96 sec, time left 0:39:49.500491 sec) loss 0.20924197
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 9000 epoch.pth
# Training epoch 10000 (took 2437.29 sec, time left -1 day, 23:59:57.603568 sec) loss 0.20921975
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed1093), Final.pth
# OurCDModel(
#   (LinearLayers): ModuleList(
#     (0): Linear(in_features=9, out_features=32, bias=True)
#     (1): Linear(in_features=32, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#     (4): Linear(in_features=9, out_features=32, bias=True)
#     (5): Linear(in_features=32, out_features=32, bias=True)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#     (7): Linear(in_features=32, out_features=1, bias=True)
#     (8): Linear(in_features=9, out_features=32, bias=True)
#     (9): Linear(in_features=32, out_features=32, bias=True)
#     (10): Linear(in_features=32, out_features=32, bias=True)
#     (11): Linear(in_features=32, out_features=1, bias=True)
#     (12): Linear(in_features=9, out_features=32, bias=True)
#     (13): Linear(in_features=32, out_features=32, bias=True)
#     (14): Linear(in_features=32, out_features=32, bias=True)
#     (15): Linear(in_features=32, out_features=1, bias=True)
#     (16): Linear(in_features=9, out_features=32, bias=True)
#     (17): Linear(in_features=32, out_features=32, bias=True)
#     (18): Linear(in_features=32, out_features=32, bias=True)
#     (19): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
DataFolder = '/data3/WZ_new_project/h5/Ideal_Data'

td = OurTrainingData([DataFolder + '/ChP_pt300_sm_1.h5',
                     ],
                    [DataFolder + '/ChP_pt300_gwm5e-2.h5',
                     DataFolder + '/ChP_pt300_gwm1e-1.h5',
                     DataFolder + '/ChP_pt300_gwm2e-1.h5',                     
                     DataFolder + '/ChP_pt300_gw5e-2.h5',
                     DataFolder + '/ChP_pt300_gw1e-1.h5',
                     DataFolder + '/ChP_pt300_gw2e-1.h5'],
                     process = 'W+Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

random_seed = torch.randint(0, 1339, (1,)).item()
OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChPgw_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')


td = OurTrainingData([DataFolder + '/ChM_pt300_sm_1.h5',
                     ],
                     [DataFolder + '/ChM_pt300_gwm5e-2.h5',
                     DataFolder + '/ChM_pt300_gwm1e-1.h5',
                     DataFolder + '/ChM_pt300_gwm2e-1.h5',                     
                     DataFolder + '/ChM_pt300_gw5e-2.h5',
                     DataFolder + '/ChM_pt300_gw1e-1.h5',
                     DataFolder + '/ChM_pt300_gw2e-1.h5'],
                     process = 'W-Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChMgW_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')
# Out:
# Loading Data Files for Process: W+Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gwm5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gwm1e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gwm2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.2}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gwm2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gw5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gw1e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gw2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.2}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gw2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_sm_1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.741835
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[ 0.0000, -0.0500]], dtype=torch.float64)   500000         0.814992
# tensor([[ 0.0000, -0.1000]], dtype=torch.float64)   500000         1.03408
# tensor([[ 0.0000, -0.2000]], dtype=torch.float64)   500000         1.91084
# tensor([[0.0000, 0.0500]], dtype=torch.float64)     500000         0.815234
# tensor([[0.0000, 0.1000]], dtype=torch.float64)     500000         1.03439
# tensor([[0.0000, 0.2000]], dtype=torch.float64)     500000         1.91103
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[ 0.0000, -0.0500]], dtype=torch.float64)     500000    500000   500000
# tensor([[ 0.0000, -0.1000]], dtype=torch.float64)     500000    500000   500000
# tensor([[ 0.0000, -0.2000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.0000, 0.0500]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0000, 0.1000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0000, 0.2000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 25.04 sec, time left 6:18:54.192602 sec) loss 0.24369545
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 10 epoch.pth
# Training epoch 100 (took 224.70 sec, time left 6:47:56.265738 sec) loss 0.21075241
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 100 epoch.pth
# Training epoch 500 (took 967.25 sec, time left 6:24:34.180625 sec) loss 0.20548353
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 500 epoch.pth
# Training epoch 1000 (took 1207.60 sec, time left 6:03:17.080262 sec) loss 0.20498711
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 1000 epoch.pth
# Training epoch 2000 (took 2428.11 sec, time left 5:23:18.679972 sec) loss 0.20475544
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 2000 epoch.pth
# Training epoch 3000 (took 2421.96 sec, time left 4:42:46.123896 sec) loss 0.20465414
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 3000 epoch.pth
# Training epoch 4000 (took 2370.40 sec, time left 4:01:01.558244 sec) loss 0.20458500
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 4000 epoch.pth
# Training epoch 5000 (took 2373.78 sec, time left 3:20:14.035042 sec) loss 0.20453475
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 5000 epoch.pth
# Training epoch 6000 (took 2365.81 sec, time left 2:39:45.774209 sec) loss 0.20449865
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 6000 epoch.pth
# Training epoch 7000 (took 2365.06 sec, time left 1:59:35.032516 sec) loss 0.20447114
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 7000 epoch.pth
# Training epoch 8000 (took 2362.22 sec, time left 1:19:35.000021 sec) loss 0.20444657
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 8000 epoch.pth
# Training epoch 9000 (took 2362.47 sec, time left 0:39:43.394885 sec) loss 0.20442781
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 9000 epoch.pth
# Training epoch 10000 (took 2375.54 sec, time left -1 day, 23:59:57.615243 sec) loss 0.20440996
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgw_par, (16 BSM, 500k, CD, Seed331), Final.pth
# Loading Data Files for Process: W-Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gwm5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gwm1e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gwm2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., -0.2}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gwm2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.05}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gw5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw1e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.1}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gw1e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gw2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0., 0.2}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gw2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_sm_1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.329009
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[ 0.0000, -0.0500]], dtype=torch.float64)   500000         0.358355
# tensor([[ 0.0000, -0.1000]], dtype=torch.float64)   500000         0.446333
# tensor([[ 0.0000, -0.2000]], dtype=torch.float64)   500000         0.798199
# tensor([[0.0000, 0.0500]], dtype=torch.float64)     500000         0.358314
# tensor([[0.0000, 0.1000]], dtype=torch.float64)     500000         0.446264
# tensor([[0.0000, 0.2000]], dtype=torch.float64)     500000         0.798166
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[ 0.0000, -0.0500]], dtype=torch.float64)     500000    500000   500000
# tensor([[ 0.0000, -0.1000]], dtype=torch.float64)     500000    500000   500000
# tensor([[ 0.0000, -0.2000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.0000, 0.0500]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0000, 0.1000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0000, 0.2000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 23.56 sec, time left 5:56:38.540737 sec) loss 0.23807110
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 10 epoch.pth
# Training epoch 100 (took 210.80 sec, time left 6:22:50.474186 sec) loss 0.21411261
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 100 epoch.pth
# Training epoch 500 (took 952.49 sec, time left 6:15:02.998754 sec) loss 0.21038303
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 500 epoch.pth
# Training epoch 1000 (took 1186.23 sec, time left 5:55:34.156848 sec) loss 0.20991157
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 1000 epoch.pth
# Training epoch 2000 (took 2393.37 sec, time left 5:17:33.967279 sec) loss 0.20962049
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 2000 epoch.pth
# Training epoch 3000 (took 2409.63 sec, time left 4:38:56.273876 sec) loss 0.20948997
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 3000 epoch.pth
# Training epoch 4000 (took 2375.66 sec, time left 3:58:41.690898 sec) loss 0.20941547
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 4000 epoch.pth
# Training epoch 5000 (took 2380.82 sec, time left 3:18:47.823380 sec) loss 0.20935938
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 5000 epoch.pth
# Training epoch 6000 (took 2375.22 sec, time left 2:38:54.568810 sec) loss 0.20931914
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 6000 epoch.pth
# Training epoch 7000 (took 2375.81 sec, time left 1:59:06.719124 sec) loss 0.20928256
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 7000 epoch.pth
# Training epoch 8000 (took 2372.01 sec, time left 1:19:20.931733 sec) loss 0.20925483
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 8000 epoch.pth
# Training epoch 9000 (took 2366.65 sec, time left 0:39:37.610188 sec) loss 0.20923196
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 9000 epoch.pth
# Training epoch 10000 (took 2365.14 sec, time left -1 day, 23:59:57.621495 sec) loss 0.20921692
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgW_par, (16 BSM, 500k, CD, Seed331), Final.pth
# OurCDModel(
#   (LinearLayers): ModuleList(
#     (0): Linear(in_features=9, out_features=32, bias=True)
#     (1): Linear(in_features=32, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#     (4): Linear(in_features=9, out_features=32, bias=True)
#     (5): Linear(in_features=32, out_features=32, bias=True)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#     (7): Linear(in_features=32, out_features=1, bias=True)
#     (8): Linear(in_features=9, out_features=32, bias=True)
#     (9): Linear(in_features=32, out_features=32, bias=True)
#     (10): Linear(in_features=32, out_features=32, bias=True)
#     (11): Linear(in_features=32, out_features=1, bias=True)
#     (12): Linear(in_features=9, out_features=32, bias=True)
#     (13): Linear(in_features=32, out_features=32, bias=True)
#     (14): Linear(in_features=32, out_features=32, bias=True)
#     (15): Linear(in_features=32, out_features=1, bias=True)
#     (16): Linear(in_features=9, out_features=32, bias=True)
#     (17): Linear(in_features=32, out_features=32, bias=True)
#     (18): Linear(in_features=32, out_features=32, bias=True)
#     (19): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## Gphi

# %%
DataFolder = '/data3/WZ_new_project/h5/Ideal_Data'

td = OurTrainingData([DataFolder + '/ChP_pt300_sm_1.h5',
                     ],
                     #DataFolder + '/ChP_pt300_sm_2.h5',
                    #DataFolder + '/ChP_pt300_sm_3.h5'],
                    [DataFolder + '/ChP_pt300_gphim5e-1.h5',
                     DataFolder + '/ChP_pt300_gphim2e-1.h5',
                     DataFolder + '/ChP_pt300_gphim5e-2.h5',
                     DataFolder + '/ChP_pt300_gphi5e-1.h5',
                     DataFolder + '/ChP_pt300_gphi2e-1.h5',
                     DataFolder + '/ChP_pt300_gphi5e-2.h5'],
                     process = 'W+Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

random_seed = torch.randint(0, 1339, (1,)).item()
OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChPgphi_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')


td = OurTrainingData([DataFolder + '/ChM_pt300_sm_1.h5',
                     ],
                     
                     #DataFolder + '/ChM_pt300_sm_2.h5',
                     #DataFolder + '/ChP_pt300_sm_3.h5'],
                    [DataFolder + '/ChM_pt300_gphim5e-1.h5',
                     DataFolder + '/ChM_pt300_gphim2e-1.h5',
                     DataFolder + '/ChM_pt300_gphim5e-2.h5',
                     DataFolder + '/ChM_pt300_gphi5e-1.h5',
                     DataFolder + '/ChM_pt300_gphi2e-1.h5',
                     DataFolder + '/ChM_pt300_gphi5e-2.h5'],
                     process = 'W-Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChMgphi_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')
# Out:
# Loading Data Files for Process: W+Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim5e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi5e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_sm_1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.741835
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)   500000         4.23431
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)   500000         0.929192
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)   500000         0.637632
# tensor([[0.5000, 0.0000]], dtype=torch.float64)     500000         7.32829
# tensor([[0.2000, 0.0000]], dtype=torch.float64)     500000         2.16749
# tensor([[0.0500, 0.0000]], dtype=torch.float64)     500000         0.947113
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.5000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.2000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0500, 0.0000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 33.62 sec, time left 8:28:53.886733 sec) loss 0.25255615
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 10 epoch.pth
# /home/chen/anaconda3/lib/python3.8/site-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# Training epoch 100 (took 290.94 sec, time left 8:50:10.362839 sec) loss 0.13897339
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 100 epoch.pth
# Training epoch 500 (took 1073.25 sec, time left 7:21:42.745585 sec) loss 0.12583785
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 500 epoch.pth
# Training epoch 1000 (took 1257.04 sec, time left 6:37:47.205526 sec) loss 0.12477845
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 1000 epoch.pth
# Training epoch 2000 (took 2487.97 sec, time left 5:42:38.483825 sec) loss 0.12433519
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 2000 epoch.pth
# Training epoch 3000 (took 2505.75 sec, time left 4:57:18.214255 sec) loss 0.12418858
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 3000 epoch.pth
# Training epoch 4000 (took 2490.93 sec, time left 4:13:22.942777 sec) loss 0.12409699
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 4000 epoch.pth
# Training epoch 5000 (took 2497.30 sec, time left 3:30:31.763493 sec) loss 0.12404161
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 5000 epoch.pth
# Training epoch 6000 (took 2500.55 sec, time left 2:48:07.372426 sec) loss 0.12400676
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 6000 epoch.pth
# Training epoch 7000 (took 2485.66 sec, time left 2:05:49.130007 sec) loss 0.12397699
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 7000 epoch.pth
# Training epoch 8000 (took 2495.20 sec, time left 1:23:46.413546 sec) loss 0.12395354
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 8000 epoch.pth
# Training epoch 9000 (took 2484.81 sec, time left 0:41:48.658306 sec) loss 0.12393165
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 9000 epoch.pth
# Training epoch 10000 (took 2498.60 sec, time left -1 day, 23:59:57.490087 sec) loss 0.12391879
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed700), Final.pth
# Loading Data Files for Process: W-Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim5e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi5e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_sm_1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.329009
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)   500000         1.66333
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)   500000         0.377384
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)   500000         0.280429
# tensor([[0.5000, 0.0000]], dtype=torch.float64)     500000         3.03977
# tensor([[0.2000, 0.0000]], dtype=torch.float64)     500000         0.927797
# tensor([[0.0500, 0.0000]], dtype=torch.float64)     500000         0.418017
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.5000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.2000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0500, 0.0000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 24.70 sec, time left 6:13:54.319589 sec) loss 0.22018236
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 10 epoch.pth
# Training epoch 100 (took 213.58 sec, time left 6:29:14.979001 sec) loss 0.14211310
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 100 epoch.pth
# Training epoch 500 (took 954.28 sec, time left 6:16:51.284222 sec) loss 0.13210842
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 500 epoch.pth
# Training epoch 1000 (took 1186.02 sec, time left 5:56:23.597309 sec) loss 0.13123031
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 1000 epoch.pth
# Training epoch 2000 (took 2363.97 sec, time left 5:15:58.415326 sec) loss 0.13091384
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 2000 epoch.pth
# Training epoch 3000 (took 2368.34 sec, time left 4:36:24.220415 sec) loss 0.13081478
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 3000 epoch.pth
# Training epoch 4000 (took 2364.79 sec, time left 3:56:47.630029 sec) loss 0.13076273
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 4000 epoch.pth
# Training epoch 5000 (took 2358.20 sec, time left 3:17:09.174864 sec) loss 0.13072272
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 5000 epoch.pth
# Training epoch 6000 (took 2373.78 sec, time left 2:37:47.849817 sec) loss 0.13068593
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 6000 epoch.pth
# Training epoch 7000 (took 2361.01 sec, time left 1:58:17.492458 sec) loss 0.13065587
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 7000 epoch.pth
# Training epoch 8000 (took 2370.51 sec, time left 1:18:51.845400 sec) loss 0.13063858
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 8000 epoch.pth
# Training epoch 9000 (took 2368.94 sec, time left 0:39:24.943041 sec) loss 0.13061868
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 9000 epoch.pth
# Training epoch 10000 (took 2372.94 sec, time left -1 day, 23:59:57.632127 sec) loss 0.13060796
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed700), Final.pth
# OurCDModel(
#   (LinearLayers): ModuleList(
#     (0): Linear(in_features=9, out_features=32, bias=True)
#     (1): Linear(in_features=32, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#     (4): Linear(in_features=9, out_features=32, bias=True)
#     (5): Linear(in_features=32, out_features=32, bias=True)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#     (7): Linear(in_features=32, out_features=1, bias=True)
#     (8): Linear(in_features=9, out_features=32, bias=True)
#     (9): Linear(in_features=32, out_features=32, bias=True)
#     (10): Linear(in_features=32, out_features=32, bias=True)
#     (11): Linear(in_features=32, out_features=1, bias=True)
#     (12): Linear(in_features=9, out_features=32, bias=True)
#     (13): Linear(in_features=32, out_features=32, bias=True)
#     (14): Linear(in_features=32, out_features=32, bias=True)
#     (15): Linear(in_features=32, out_features=1, bias=True)
#     (16): Linear(in_features=9, out_features=32, bias=True)
#     (17): Linear(in_features=32, out_features=32, bias=True)
#     (18): Linear(in_features=32, out_features=32, bias=True)
#     (19): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
DataFolder = '/data3/WZ_new_project/h5/Ideal_Data'

td = OurTrainingData([DataFolder + '/ChP_pt300_sm_1.h5',
                     ],
                     #DataFolder + '/ChP_pt300_sm_2.h5',
                    #DataFolder + '/ChP_pt300_sm_3.h5'],
                    [DataFolder + '/ChP_pt300_gphim5e-1.h5',
                     DataFolder + '/ChP_pt300_gphim2e-1.h5',
                     DataFolder + '/ChP_pt300_gphim5e-2.h5',
                     DataFolder + '/ChP_pt300_gphi5e-1.h5',
                     DataFolder + '/ChP_pt300_gphi2e-1.h5',
                     DataFolder + '/ChP_pt300_gphi5e-2.h5'],
                     process = 'W+Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

random_seed = torch.randint(0, 1339, (1,)).item()
OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChPgphi_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')


td = OurTrainingData([DataFolder + '/ChM_pt300_sm_1.h5',
                     ],
                     
                     #DataFolder + '/ChM_pt300_sm_2.h5',
                     #DataFolder + '/ChP_pt300_sm_3.h5'],
                    [DataFolder + '/ChM_pt300_gphim5e-1.h5',
                     DataFolder + '/ChM_pt300_gphim2e-1.h5',
                     DataFolder + '/ChM_pt300_gphim5e-2.h5',
                     DataFolder + '/ChM_pt300_gphi5e-1.h5',
                     DataFolder + '/ChM_pt300_gphi2e-1.h5',
                     DataFolder + '/ChM_pt300_gphi5e-2.h5'],
                     process = 'W-Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChMgphi_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')
# Out:
# Loading Data Files for Process: W+Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim5e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi5e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_sm_1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.741835
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)   500000         4.23431
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)   500000         0.929192
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)   500000         0.637632
# tensor([[0.5000, 0.0000]], dtype=torch.float64)     500000         7.32829
# tensor([[0.2000, 0.0000]], dtype=torch.float64)     500000         2.16749
# tensor([[0.0500, 0.0000]], dtype=torch.float64)     500000         0.947113
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.5000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.2000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0500, 0.0000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 25.96 sec, time left 6:32:52.376405 sec) loss 0.23253497
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 10 epoch.pth
# Training epoch 100 (took 215.85 sec, time left 6:35:00.141605 sec) loss 0.13707754
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 100 epoch.pth
# Training epoch 500 (took 960.23 sec, time left 6:19:50.863224 sec) loss 0.12537567
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 500 epoch.pth
# Training epoch 1000 (took 1188.66 sec, time left 5:58:12.502998 sec) loss 0.12450713
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 1000 epoch.pth
# Training epoch 2000 (took 2407.70 sec, time left 5:19:41.635595 sec) loss 0.12423333
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 2000 epoch.pth
# Training epoch 3000 (took 2427.46 sec, time left 4:40:52.327977 sec) loss 0.12414326
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 3000 epoch.pth
# Training epoch 4000 (took 2420.97 sec, time left 4:01:04.223843 sec) loss 0.12408208
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 4000 epoch.pth
# Training epoch 5000 (took 2409.56 sec, time left 3:20:51.578660 sec) loss 0.12404472
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 5000 epoch.pth
# Training epoch 6000 (took 2396.13 sec, time left 2:40:31.007848 sec) loss 0.12401601
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 6000 epoch.pth
# Training epoch 7000 (took 2379.96 sec, time left 2:00:10.491913 sec) loss 0.12399474
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 7000 epoch.pth
# Training epoch 8000 (took 2392.41 sec, time left 1:20:03.223412 sec) loss 0.12398154
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 8000 epoch.pth
# Training epoch 9000 (took 2380.32 sec, time left 0:39:57.914213 sec) loss 0.12395941
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 9000 epoch.pth
# Training epoch 10000 (took 2382.41 sec, time left -1 day, 23:59:57.601476 sec) loss 0.12394965
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1022), Final.pth
# Loading Data Files for Process: W-Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim5e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi5e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_sm_1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.329009
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)   500000         1.66333
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)   500000         0.377384
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)   500000         0.280429
# tensor([[0.5000, 0.0000]], dtype=torch.float64)     500000         3.03977
# tensor([[0.2000, 0.0000]], dtype=torch.float64)     500000         0.927797
# tensor([[0.0500, 0.0000]], dtype=torch.float64)     500000         0.418017
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.5000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.2000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0500, 0.0000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 25.38 sec, time left 6:24:04.386661 sec) loss 0.22895706
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 10 epoch.pth
# Training epoch 100 (took 218.66 sec, time left 6:38:38.097186 sec) loss 0.14385155
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 100 epoch.pth
# Training epoch 500 (took 950.36 sec, time left 6:17:25.998100 sec) loss 0.13222252
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 500 epoch.pth
# Training epoch 1000 (took 1189.93 sec, time left 5:57:15.222275 sec) loss 0.13145284
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 1000 epoch.pth
# Training epoch 2000 (took 2357.13 sec, time left 5:15:54.043648 sec) loss 0.13103692
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 2000 epoch.pth
# Training epoch 3000 (took 2353.72 sec, time left 4:35:47.568714 sec) loss 0.13092260
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 3000 epoch.pth
# Training epoch 4000 (took 2363.19 sec, time left 3:56:21.670097 sec) loss 0.13085307
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 4000 epoch.pth
# Training epoch 5000 (took 2363.44 sec, time left 3:16:57.103080 sec) loss 0.13080652
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 5000 epoch.pth
# Training epoch 6000 (took 2346.02 sec, time left 2:37:21.299456 sec) loss 0.13076581
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 6000 epoch.pth
# Training epoch 7000 (took 2385.32 sec, time left 1:58:10.837722 sec) loss 0.13074058
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 7000 epoch.pth
# Training epoch 8000 (took 2351.51 sec, time left 1:18:43.217324 sec) loss 0.13071086
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 8000 epoch.pth
# Training epoch 9000 (took 2357.19 sec, time left 0:39:19.805798 sec) loss 0.13069108
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 9000 epoch.pth
# Training epoch 10000 (took 2362.10 sec, time left -1 day, 23:59:57.637839 sec) loss 0.13067757
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1022), Final.pth
# OurCDModel(
#   (LinearLayers): ModuleList(
#     (0): Linear(in_features=9, out_features=32, bias=True)
#     (1): Linear(in_features=32, out_features=32, bias=True)
#     (2): Linear(in_features=32, out_features=32, bias=True)
#     (3): Linear(in_features=32, out_features=1, bias=True)
#     (4): Linear(in_features=9, out_features=32, bias=True)
#     (5): Linear(in_features=32, out_features=32, bias=True)
#     (6): Linear(in_features=32, out_features=32, bias=True)
#     (7): Linear(in_features=32, out_features=1, bias=True)
#     (8): Linear(in_features=9, out_features=32, bias=True)
#     (9): Linear(in_features=32, out_features=32, bias=True)
#     (10): Linear(in_features=32, out_features=32, bias=True)
#     (11): Linear(in_features=32, out_features=1, bias=True)
#     (12): Linear(in_features=9, out_features=32, bias=True)
#     (13): Linear(in_features=32, out_features=32, bias=True)
#     (14): Linear(in_features=32, out_features=32, bias=True)
#     (15): Linear(in_features=32, out_features=1, bias=True)
#     (16): Linear(in_features=9, out_features=32, bias=True)
#     (17): Linear(in_features=32, out_features=32, bias=True)
#     (18): Linear(in_features=32, out_features=32, bias=True)
#     (19): Linear(in_features=32, out_features=1, bias=True)
#   )
# )

# %%
DataFolder = '/data3/WZ_new_project/h5/Ideal_Data'

td = OurTrainingData([DataFolder + '/ChP_pt300_sm_1.h5',
                     ],
                     #DataFolder + '/ChP_pt300_sm_2.h5',
                    #DataFolder + '/ChP_pt300_sm_3.h5'],
                    [DataFolder + '/ChP_pt300_gphim5e-1.h5',
                     DataFolder + '/ChP_pt300_gphim2e-1.h5',
                     DataFolder + '/ChP_pt300_gphim5e-2.h5',
                     DataFolder + '/ChP_pt300_gphi5e-1.h5',
                     DataFolder + '/ChP_pt300_gphi2e-1.h5',
                     DataFolder + '/ChP_pt300_gphi5e-2.h5'],
                     process = 'W+Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

random_seed = torch.randint(0, 1339, (1,)).item()
OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChPgphi_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')


td = OurTrainingData([DataFolder + '/ChM_pt300_sm_1.h5',
                     ],
                     
                     #DataFolder + '/ChM_pt300_sm_2.h5',
                     #DataFolder + '/ChP_pt300_sm_3.h5'],
                    [DataFolder + '/ChM_pt300_gphim5e-1.h5',
                     DataFolder + '/ChM_pt300_gphim2e-1.h5',
                     DataFolder + '/ChM_pt300_gphim5e-2.h5',
                     DataFolder + '/ChM_pt300_gphi5e-1.h5',
                     DataFolder + '/ChM_pt300_gphi2e-1.h5',
                     DataFolder + '/ChM_pt300_gphi5e-2.h5'],
                     process = 'W-Z', parameters =['Gphi[TeV**-2]', 'GW[TeV**-2]'], 
                     SMNLimits=int(3e6),
                     BSMNLimits=int(5e5))

NumEpochs = int(1e4)

td.Data = td.Data[:, :7]
td.CurateAngles([3, 5])

Data, ParVal, Labels, Weights = td.Data, td.ParVal, td.Labels, td.Weights
Data, ParVal, Labels, Weights = Data.float(), ParVal.float(), Labels.float(), Weights.float()

MD = OurCDModel(NumberOfParameters=2, AR=[9,32,32,32,1])
MD.InitPreprocess(Data, ParVal)

OT = OurTrainer(NumEpochs = NumEpochs)
OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))

OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
        Name = 'ChMgphi_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')
# Out:
# Loading Data Files for Process: W+Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim5e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphim5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphim5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi5e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi2e-1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_gphi5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_gphi5e-2.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChP_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChP_pt300_sm_1.dat.gz
# Charge = 1 --- Process = W+Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.741835
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)   500000         4.23431
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)   500000         0.929192
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)   500000         0.637632
# tensor([[0.5000, 0.0000]], dtype=torch.float64)     500000         7.32829
# tensor([[0.2000, 0.0000]], dtype=torch.float64)     500000         2.16749
# tensor([[0.0500, 0.0000]], dtype=torch.float64)     500000         0.947113
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.5000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.2000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0500, 0.0000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 23.57 sec, time left 5:56:45.550543 sec) loss 0.21829982
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 10 epoch.pth
# Training epoch 100 (took 211.03 sec, time left 6:23:13.116500 sec) loss 0.13651106
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 100 epoch.pth
# Training epoch 500 (took 934.53 sec, time left 6:09:26.810125 sec) loss 0.12558341
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 500 epoch.pth
# Training epoch 1000 (took 1167.50 sec, time left 5:50:06.367374 sec) loss 0.12456873
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 1000 epoch.pth
# Training epoch 2000 (took 2323.98 sec, time left 5:10:30.832468 sec) loss 0.12426113
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 2000 epoch.pth
# Training epoch 3000 (took 2342.88 sec, time left 4:32:13.734511 sec) loss 0.12414652
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 3000 epoch.pth
# Training epoch 4000 (took 2345.85 sec, time left 3:53:38.197692 sec) loss 0.12407698
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 4000 epoch.pth
# Training epoch 5000 (took 2334.18 sec, time left 3:14:38.873161 sec) loss 0.12402789
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 5000 epoch.pth
# Training epoch 6000 (took 2332.65 sec, time left 2:35:40.236999 sec) loss 0.12399366
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 6000 epoch.pth
# Training epoch 7000 (took 2332.90 sec, time left 1:56:43.419265 sec) loss 0.12396695
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 7000 epoch.pth
# Training epoch 8000 (took 2345.81 sec, time left 1:17:50.805339 sec) loss 0.12394297
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 8000 epoch.pth
# Training epoch 9000 (took 2348.13 sec, time left 0:38:55.517726 sec) loss 0.12392493
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 9000 epoch.pth
# Training epoch 10000 (took 2353.46 sec, time left -1 day, 23:59:57.660584 sec) loss 0.12390827
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), 10000 epoch.pth
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChPgphi_par, (16 BSM, 500k, CD, Seed1057), Final.pth
# Loading Data Files for Process: W-Z, with new physics Parameters: ['Gphi[TeV**-2]', 'GW[TeV**-2]']
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim5e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphim5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {-0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphim5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.5, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi5e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi2e-1.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.2, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi2e-1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_gphi5e-2.h5
# ##### File Info:
# {Gphi[TeV**-2], GW[TeV**-2]} = {0.05, 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_gphi5e-2.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Reading file .../data3/WZ_new_project/h5/Ideal_Data/ChM_pt300_sm_1.h5
# ##### File Info:
# SM = {0., 0.}[TeV**-2] data, Ideal Events.
# Event format: {{s, θ, θZ, ϕZ, θWrec, ϕWrec, PtZ}, weight}.
# Converted from /data3/WZ_new_project/dat/Ideal_Events/ChM_pt300_sm_1.dat.gz
# Charge = -1 --- Process = W-Z
# #####
#
# Loaded SM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']           #Data    XS[pb](avg.w)
# ---------------------------------------  -------  ---------------
# tensor([[0., 0.]], dtype=torch.float64)  3000000         0.329009
#
# Loaded BSM Files:
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Data    XS[pb](avg.w)
# -------------------------------------------------  -------  ---------------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)   500000         1.66333
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)   500000         0.377384
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)   500000         0.280429
# tensor([[0.5000, 0.0000]], dtype=torch.float64)     500000         3.03977
# tensor([[0.2000, 0.0000]], dtype=torch.float64)     500000         0.927797
# tensor([[0.0500, 0.0000]], dtype=torch.float64)     500000         0.418017
#
# Paired BSM/SM Datasets:
#
# ['Gphi[TeV**-2]', 'GW[TeV**-2]']                     #Ev.BSM    #Ev.SM    Check
# -------------------------------------------------  ---------  --------  -------
# tensor([[-0.5000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.2000,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[-0.0500,  0.0000]], dtype=torch.float64)     500000    500000   500000
# tensor([[0.5000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.2000, 0.0000]], dtype=torch.float64)       500000    500000   500000
# tensor([[0.0500, 0.0000]], dtype=torch.float64)       500000    500000   500000
# ####
# Anlges at position [3, 5] have been converted to Sin and Cos and put at the last columns of the Data.
# ####
# Initializing Preprocesses Variables
# Training epoch 10 (took 23.82 sec, time left 6:00:26.573680 sec) loss 0.19336055
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1057), 10 epoch.pth
# Training epoch 100 (took 213.24 sec, time left 6:27:13.497290 sec) loss 0.14184271
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1057), 100 epoch.pth
# Training epoch 500 (took 942.36 sec, time left 6:12:41.838569 sec) loss 0.13223876
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1057), 500 epoch.pth
# Training epoch 1000 (took 1167.28 sec, time left 5:51:36.803427 sec) loss 0.13127579
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1057), 1000 epoch.pth
# Training epoch 2000 (took 2333.56 sec, time left 5:11:49.352871 sec) loss 0.13094018
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1057), 2000 epoch.pth
# Training epoch 3000 (took 2354.76 sec, time left 4:33:27.238653 sec) loss 0.13084246
# Model successfully saved.
# Path: /home/chen/Documents/2DQuadraticClassifier/TrainedModels/ChMgphi_par, (16 BSM, 500k, CD, Seed1057), 3000 epoch.pth
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-525b35385a6d> in <module>
#      63 OT.SetSaveAfterEpochs([10,100,500]+list(range(1000, 11000, 1000)))
#      64
# ---> 65 OT.Train(MD, Data = Data, Parameters = ParVal, Labels=Labels, Weights= Weights, bs = 100000,
#      66         Name = 'ChMgphi_par, (16 BSM, 500k, CD, Seed%d), '%(random_seed), Folder = os.getcwd()+'/TrainedModels/')
#
# ~/Documents/2DQuadraticClassifier/OurTrainingTools2D.py in Train(self, model, Data, Parameters, Labels, Weights, bs, L1perUnit, UseGPU, Name, Folder, WeightClipping, L1Max)
#     736         if next(model.parameters()).is_cuda:
#     737             print('Model is on cuda. No estimate possible anymore.')
# --> 738             return None
#     739         else:
#     740             before = torch.cuda.memory_allocated()
#
# ~/Documents/2DQuadraticClassifier/OurTrainingTools2D.py in Forward(self, Data, Parameters)
#     520         for i in range(self.NumberOfParameters+1):
#     521             EntryIterator += i
# --> 522             DiagonalEntry = True
#     523             for j in range(self.NumberOfParameters+1-i):
#     524                 if NetworkIterator == -1:
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# ~/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# KeyboardInterrupt:
